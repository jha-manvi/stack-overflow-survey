# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data/survey_results_public.csv',na_values=['Missing'])

# %%
df
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# ...           ...                             ...                 ...
# 65432       65433  I am a developer by profession     18-24 years old
# 65433       65434  I am a developer by profession     25-34 years old
# 65434       65435  I am a developer by profession     25-34 years old
# 65435       65436  I am a developer by profession     18-24 years old
# 65436       65437     I code primarily as a hobby     18-24 years old
#
#                 Employment                            RemoteWork   Check  \
# ...

# %%
df.shape
# Out:
# (65437, 114)

# %%
df.columns.values
# Out:
# array(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'Check', 'CodingActivities', 'EdLevel', 'LearnCode',
#        'LearnCodeOnline', 'TechDoc', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool',
#        'BuildvsBuy', 'TechEndorse', 'Country', 'Currency', 'CompTotal',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'LanguageAdmired', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'DatabaseAdmired',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'PlatformAdmired', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'WebframeAdmired',
#        'EmbeddedHaveWorkedWith', 'EmbeddedWantToWorkWith',
#        'EmbeddedAdmired', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'MiscTechAdmired',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'ToolsTechAdmired', 'NEWCollabToolsHaveWorkedWith',
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df
# Out:
#        qid            qname  \
# 0     QID2       MainBranch
# 1   QID127              Age
# 2   QID296       Employment
# 3   QID308       RemoteWork
# 4   QID341            Check
# ..     ...              ...
# 82  QID337   JobSatPoints_7
# 83  QID337   JobSatPoints_8
# 84  QID337   JobSatPoints_9
# 85  QID337  JobSatPoints_10
# 86  QID337  JobSatPoints_11
#
#                                              question force_resp type selector
# 0   Which of the following options best describes ...       True   MC     SAVR
# 1                                  What is your age?*       True   MC     SAVR
# 2   Which of the following best describes your cur...       True   MC     MAVR
# 3   Which best describes your current work situation?      False   MC     SAVR
# 4   Just checking to make sure you are paying atte...       True   MC     SAVR
# ..                                                ...        ...  ...      ...
# ...

# %%
pd.set_option('display.max_rows', 87)

# %%
schema_df
# Out:
#        qid                 qname  \
# 0     QID2            MainBranch
# 1   QID127                   Age
# 2   QID296            Employment
# 3   QID308            RemoteWork
# 4   QID341                 Check
# 5   QID297      CodingActivities
# 6    QID25               EdLevel
# 7   QID276             LearnCode
# 8   QID281       LearnCodeOnline
# 9   QID331               TechDoc
# 10   QID32             YearsCode
# 11   QID34          YearsCodePro
# 12   QID31               DevType
# 13   QID29               OrgSize
# 14  QID278     PurchaseInfluence
# 15  QID279            BuyNewTool
# 16  QID330            BuildvsBuy
# 17  QID335           TechEndorse
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21  QID233              Language
# 22  QID262              Database
# 23  QID263              Platform
# 24  QID264              Webframe
# 25  QID340              Embedded
# 26  QID265              MiscTech
# ...

# %%
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2                     I am a developer by profession
# 2           3                     I am a developer by profession
# 3           4                              I am learning to code
# 4           5                     I am a developer by profession
# 5           6                        I code primarily as a hobby
# 6           7  I am not primarily a developer, but I write co...
# 7           8                              I am learning to code
# 8           9                        I code primarily as a hobby
# 9          10                     I am a developer by profession
#
#                   Age                                         Employment  \
# 0  Under 18 years old                                Employed, full-time
# 1     35-44 years old                                Employed, full-time
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %%
pd.set_option('display.max_colwidth', None)

# %%
schema_df
# Out:
#        qid                 qname  \
# 0     QID2            MainBranch
# 1   QID127                   Age
# 2   QID296            Employment
# 3   QID308            RemoteWork
# 4   QID341                 Check
# 5   QID297      CodingActivities
# 6    QID25               EdLevel
# 7   QID276             LearnCode
# 8   QID281       LearnCodeOnline
# 9   QID331               TechDoc
# 10   QID32             YearsCode
# 11   QID34          YearsCodePro
# 12   QID31               DevType
# 13   QID29               OrgSize
# 14  QID278     PurchaseInfluence
# 15  QID279            BuyNewTool
# 16  QID330            BuildvsBuy
# 17  QID335           TechEndorse
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21  QID233              Language
# 22  QID262              Database
# 23  QID263              Platform
# 24  QID264              Webframe
# 25  QID340              Embedded
# 26  QID265              MiscTech
# ...

# %%
df['RemoteWork']
# Out:
# 0                                      Remote
# 1                                      Remote
# 2                                      Remote
# 3                                         NaN
# 4                                         NaN
#                          ...
# 65432                                  Remote
# 65433                                  Remote
# 65434                               In-person
# 65435    Hybrid (some remote, some in-person)
# 65436                                     NaN
# Name: RemoteWork, Length: 65437, dtype: object

# %%
df.MainBranch.value_counts()
# Out:
# I am a developer by profession                                                           50207
# I am not primarily a developer, but I write code sometimes as part of my work/studies     6511
# I am learning to code                                                                     3875
# I code primarily as a hobby                                                               3334
# I used to be a developer by profession, but no longer am                                  1510
# Name: MainBranch, dtype: int64

# %%
df.MainBranch
# Out:
# 0        I am a developer by profession
# 1        I am a developer by profession
# 2        I am a developer by profession
# 3                 I am learning to code
# 4        I am a developer by profession
#                       ...
# 65432    I am a developer by profession
# 65433    I am a developer by profession
# 65434    I am a developer by profession
# 65435    I am a developer by profession
# 65436       I code primarily as a hobby
# Name: MainBranch, Length: 65437, dtype: object

# %%
df.loc[0]
# Out:
# ResponseId                                          1
# MainBranch             I am a developer by profession
# Age                                Under 18 years old
# Employment                        Employed, full-time
# RemoteWork                                     Remote
#                                     ...
# JobSatPoints_11                                   NaN
# SurveyLength                                      NaN
# SurveyEase                                        NaN
# ConvertedCompYearly                               NaN
# JobSat                                            NaN
# Name: 0, Length: 114, dtype: object

# %%
df.loc[0:5,['RemoteWork','MainBranch']]
# Out:
#   RemoteWork                      MainBranch
# 0     Remote  I am a developer by profession
# 1     Remote  I am a developer by profession
# 2     Remote  I am a developer by profession
# 3        NaN           I am learning to code
# 4        NaN  I am a developer by profession
# 5        NaN     I code primarily as a hobby

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                                    CodingActivities  \
# 0                                                             Hobby
# 1  Hobby;Contribute to open-source projects;Other (please specify):
# 2  Hobby;Contribute to open-source projects;Other (please specify):
# ...

# %%
schema_df
# Out:
#        qid                 qname  \
# 0     QID2            MainBranch
# 1   QID127                   Age
# 2   QID296            Employment
# 3   QID308            RemoteWork
# 4   QID341                 Check
# 5   QID297      CodingActivities
# 6    QID25               EdLevel
# 7   QID276             LearnCode
# 8   QID281       LearnCodeOnline
# 9   QID331               TechDoc
# 10   QID32             YearsCode
# 11   QID34          YearsCodePro
# 12   QID31               DevType
# 13   QID29               OrgSize
# 14  QID278     PurchaseInfluence
# 15  QID279            BuyNewTool
# 16  QID330            BuildvsBuy
# 17  QID335           TechEndorse
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21  QID233              Language
# 22  QID262              Database
# 23  QID263              Platform
# 24  QID264              Webframe
# 25  QID340              Embedded
# 26  QID265              MiscTech
# ...

# %%
schema_df.set_index('qname',inplace=True)

# %%
schema_df
# Out:
#                          qid  \
# qname
# MainBranch              QID2
# Age                   QID127
# Employment            QID296
# RemoteWork            QID308
# Check                 QID341
# CodingActivities      QID297
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# TechDoc               QID331
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# BuyNewTool            QID279
# BuildvsBuy            QID330
# TechEndorse           QID335
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# Embedded              QID340
# MiscTech              QID265
# ToolsTech             QID275
# NEWCollabTools        QID274
# OpSys                  QID71
# ...

# %%
schema_df.loc['MainBranch','question']
# Out:
# 'Which of the following options best describes you today? For the purpose of this survey, a developer is "someone who writes code".*'

# %%
schema_df.sort_index()
# Out:
#                          qid  \
# qname
# AIAcc                 QID316
# AIBen                 QID324
# AIChallenges          QID346
# AIComplex             QID343
# AIEthics              QID339
# AINext                QID320
# AISearchDev           QID327
# AISelect              QID314
# AISent                QID315
# AIThreat              QID338
# AITool                QID319
# Age                   QID127
# BuildvsBuy            QID330
# BuyNewTool            QID279
# Check                 QID341
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Embedded              QID340
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# Frustration           QID342
# ICorPM                QID287
# ...

# %%
schema_df
# Out:
#                          qid  \
# qname
# MainBranch              QID2
# Age                   QID127
# Employment            QID296
# RemoteWork            QID308
# Check                 QID341
# CodingActivities      QID297
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# TechDoc               QID331
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# BuyNewTool            QID279
# BuildvsBuy            QID330
# TechEndorse           QID335
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# Embedded              QID340
# MiscTech              QID265
# ToolsTech             QID275
# NEWCollabTools        QID274
# OpSys                  QID71
# ...

# %%
schema_df[schema_df['type']!='MC']
# Out:
#                      qid  \
# qname
# CompTotal          QID51
# Language          QID233
# Database          QID262
# Platform          QID263
# Webframe          QID264
# Embedded          QID340
# MiscTech          QID265
# ToolsTech         QID275
# NEWCollabTools    QID274
# OpSys              QID71
# OfficeStackAsync  QID282
# OfficeStackSync   QID307
# AISearchDev       QID327
# AITool            QID319
# AINext            QID320
# WorkExp           QID288
# Knowledge         QID289
# Frequency         QID290
# JobSatPoints      QID337
#
#                                                                                                                                                                                                                                                                                                                                  question  \
# qname
# ...

# %%
filt=schema_df['type']!='MC'

# %%
schema_df[filt].head()
# Out:
#               qid  \
# qname
# CompTotal   QID51
# Language   QID233
# Database   QID262
# Platform   QID263
# Webframe   QID264
#
#                                                                                                                                                                                                                                                                                                                           question  \
# qname
# CompTotal  What is your current total <b>annual</b> compensation (salary, bonuses, and perks, before taxes and deductions)? Please enter a whole number in the box below, without any punctuation.  If you are paid hourly, please estimate an equivalent yearly salary. If you prefer not to answer, please leave the box empty.
# ...

# %%
schema_df.loc[filt,['type','selector']].head()
# Out:
#              type selector
# qname
# CompTotal      TE       SL
# Language   Matrix   Likert
# Database   Matrix   Likert
# Platform   Matrix   Likert
# Webframe   Matrix   Likert

# %%
schema_df.sort_index()
# Out:
#                          qid  \
# qname
# AIAcc                 QID316
# AIBen                 QID324
# AIChallenges          QID346
# AIComplex             QID343
# AIEthics              QID339
# AINext                QID320
# AISearchDev           QID327
# AISelect              QID314
# AISent                QID315
# AIThreat              QID338
# AITool                QID319
# Age                   QID127
# BuildvsBuy            QID330
# BuyNewTool            QID279
# Check                 QID341
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Embedded              QID340
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# Frustration           QID342
# ICorPM                QID287
# ...

# %%
high_salary_india = (df['CompTotal']>1500000) & (df['Country']=='India')

# %%
df.loc[high_salary_india,['CompTotal','Currency','LanguageHaveWorkedWith']]
# Out:
#        CompTotal           Currency  \
# 665    4000000.0  INR\tIndian rupee
# 695    3600000.0  INR\tIndian rupee
# 825    3500000.0  INR\tIndian rupee
# 1138   1720000.0  INR\tIndian rupee
# 1353   8000000.0  INR\tIndian rupee
# ...          ...                ...
# 63899  2100000.0  INR\tIndian rupee
# 64187  8800000.0  INR\tIndian rupee
# 64194  1600000.0  INR\tIndian rupee
# 64503  2000000.0  INR\tIndian rupee
# 65171  2500000.0  INR\tIndian rupee
#
#                                             LanguageHaveWorkedWith
# 665                           JavaScript;PHP;Python;SQL;TypeScript
# 695                                              Apex;C;Cobol;Ruby
# 825                              HTML/CSS;Java;JavaScript;Ruby;SQL
# 1138                                  JavaScript;Python;TypeScript
# 1353                                HTML/CSS;JavaScript;TypeScript
# ...                                                            ...
# ...

# %%
df.columns.values
# Out:
# array(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'Check', 'CodingActivities', 'EdLevel', 'LearnCode',
#        'LearnCodeOnline', 'TechDoc', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool',
#        'BuildvsBuy', 'TechEndorse', 'Country', 'Currency', 'CompTotal',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'LanguageAdmired', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'DatabaseAdmired',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'PlatformAdmired', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'WebframeAdmired',
#        'EmbeddedHaveWorkedWith', 'EmbeddedWantToWorkWith',
#        'EmbeddedAdmired', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'MiscTechAdmired',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'ToolsTechAdmired', 'NEWCollabToolsHaveWorkedWith',
# ...

# %%
df.rename(columns={'EdLevel':'EduLevel'},inplace=True)

# %%
df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                                    CodingActivities  \
# 0                                                             Hobby
# 1  Hobby;Contribute to open-source projects;Other (please specify):
# 2  Hobby;Contribute to open-source projects;Other (please specify):
# ...

# %%
df['SurveyLength'].unique()
# Out:
# array([nan, 'Appropriate in length', 'Too long', 'Too short'],
#       dtype=object)

# %%
schema_df.sort_index()
# Out:
#                          qid  \
# qname
# AIAcc                 QID316
# AIBen                 QID324
# AIChallenges          QID346
# AIComplex             QID343
# AIEthics              QID339
# AINext                QID320
# AISearchDev           QID327
# AISelect              QID314
# AISent                QID315
# AIThreat              QID338
# AITool                QID319
# Age                   QID127
# BuildvsBuy            QID330
# BuyNewTool            QID279
# Check                 QID341
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Embedded              QID340
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# Frustration           QID342
# ICorPM                QID287
# ...

# %%
df['Check'].value_counts()
# Out:
# Apples    65437
# Name: Check, dtype: int64

# %%
schema_df.sort_values('qname')
# Out:
#                          qid  \
# qname
# AIAcc                 QID316
# AIBen                 QID324
# AIChallenges          QID346
# AIComplex             QID343
# AIEthics              QID339
# AINext                QID320
# AISearchDev           QID327
# AISelect              QID314
# AISent                QID315
# AIThreat              QID338
# AITool                QID319
# Age                   QID127
# BuildvsBuy            QID330
# BuyNewTool            QID279
# Check                 QID341
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Embedded              QID340
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# Frustration           QID342
# ICorPM                QID287
# ...

# %%
df[['Country','Age','CompTotal']].sort_values(by=['Country','CompTotal'],ascending=[True,False])
# Out:
#            Country              Age     CompTotal
# 17374  Afghanistan  55-64 years old  1.000000e+53
# 8814   Afghanistan  35-44 years old  1.000000e+44
# 60331  Afghanistan  18-24 years old  9.347772e+09
# 1565   Afghanistan  25-34 years old  2.500000e+08
# 37548  Afghanistan  25-34 years old  8.000000e+05
# ...            ...              ...           ...
# 65430          NaN  18-24 years old           NaN
# 65432          NaN  18-24 years old           NaN
# 65433          NaN  25-34 years old           NaN
# 65434          NaN  25-34 years old           NaN
# 65436          NaN  18-24 years old           NaN
#
# [65437 rows x 3 columns]

# %%
df.nsmallest(10,'CompTotal')
# Out:
#       ResponseId                      MainBranch              Age  \
# 697          698  I am a developer by profession  18-24 years old
# 1256        1257  I am a developer by profession  45-54 years old
# 1930        1931  I am a developer by profession  45-54 years old
# 2087        2088  I am a developer by profession  35-44 years old
# 2290        2291  I am a developer by profession  35-44 years old
# 2607        2608  I am a developer by profession  18-24 years old
# 2736        2737  I am a developer by profession  18-24 years old
# 3125        3126  I am a developer by profession  25-34 years old
# 3962        3963  I am a developer by profession  35-44 years old
# 4059        4060  I am a developer by profession  35-44 years old
#
#                                                                                        Employment  \
# 697                                                                           Employed, full-time
# ...

# %%
df.mean()
# Out:
# ResponseId              3.271900e+04
# CompTotal              2.963841e+145
# WorkExp                 1.146696e+01
# JobSatPoints_1          1.858109e+01
# JobSatPoints_4          7.522140e+00
# JobSatPoints_5          1.006086e+01
# JobSatPoints_6          2.434323e+01
# JobSatPoints_7          2.296522e+01
# JobSatPoints_8          2.027817e+01
# JobSatPoints_9          1.616943e+01
# JobSatPoints_10         1.095571e+01
# JobSatPoints_11         9.953948e+00
# ConvertedCompYearly     8.615529e+04
# JobSat                  6.935041e+00
# dtype: float64

# %%
schema_df.sort_index()
# Out:
#                          qid  \
# qname
# AIAcc                 QID316
# AIBen                 QID324
# AIChallenges          QID346
# AIComplex             QID343
# AIEthics              QID339
# AINext                QID320
# AISearchDev           QID327
# AISelect              QID314
# AISent                QID315
# AIThreat              QID338
# AITool                QID319
# Age                   QID127
# BuildvsBuy            QID330
# BuyNewTool            QID279
# Check                 QID341
# CodingActivities      QID297
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Embedded              QID340
# Employment            QID296
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# Frustration           QID342
# ICorPM                QID287
# ...

# %%
df['TBranch'].value_counts()
# Out:
# Yes    29960
# No     14517
# Name: TBranch, dtype: int64

# %%
df['TBranch'].value_counts(normalize=True)
# Out:
# Yes    0.673607
# No     0.326393
# Name: TBranch, dtype: float64

# %%
country_grp=df.groupby(['Country'])

# %%
country_grp['RemoteWork'].value_counts().head(500)
# Out:
# Country      RemoteWork
# Afghanistan  Hybrid (some remote, some in-person)    17
#              In-person                               13
#              Remote                                  10
# Albania      Hybrid (some remote, some in-person)    14
#              Remote                                  14
#                                                      ..
# Zambia       Hybrid (some remote, some in-person)     4
#              Remote                                   3
# Zimbabwe     Hybrid (some remote, some in-person)     8
#              In-person                                6
#              Remote                                   6
# Name: RemoteWork, Length: 476, dtype: int64

# %%
pd.set_option('display.max_rows', 500)

# %%
country_grp['RemoteWork'].value_counts(normalize=True).head(500)
# Out:
# Country                                               RemoteWork
# Afghanistan                                           Hybrid (some remote, some in-person)    0.425000
#                                                       In-person                               0.325000
#                                                       Remote                                  0.250000
# Albania                                               Hybrid (some remote, some in-person)    0.368421
#                                                       Remote                                  0.368421
#                                                       In-person                               0.263158
# Algeria                                               Remote                                  0.448980
#                                                       Hybrid (some remote, some in-person)    0.387755
# ...

# %%
country_grp['CompTotal'].mean()
# Out:
# Country
# Afghanistan                                              4.166667e+51
# Albania                                                  1.493638e+06
# Algeria                                                  7.415032e+05
# Andorra                                                  9.400000e+04
# Angola                                                   3.412757e+07
# Antigua and Barbuda                                      1.909000e+05
# Argentina                                                9.844781e+06
# Armenia                                                  1.222941e+07
# Australia                                                1.636610e+05
# Austria                                                  6.927775e+04
# Azerbaijan                                               4.451429e+04
# Bahamas                                                           NaN
# Bahrain                                                  2.320200e+04
# ...

# %%
country_grp['CompTotal'].agg(['median','mean','min','max'])
# Out:
#                                                              median  \
# Country
# Afghanistan                                            2.600000e+04
# Albania                                                9.000000e+04
# Algeria                                                6.000000e+05
# Andorra                                                4.000000e+04
# Angola                                                 1.350000e+06
# Antigua and Barbuda                                    1.909000e+05
# Argentina                                              7.200000e+04
# Armenia                                                2.500000e+06
# Australia                                              1.455000e+05
# Austria                                                6.300000e+04
# Azerbaijan                                             3.510000e+04
# Bahamas                                                         NaN
# Bahrain                                                1.440000e+04
# ...

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                                               26
# Albania                                                   10
# Algeria                                                   37
# Andorra                                                    8
# Angola                                                     9
# Antigua and Barbuda                                        0
# Argentina                                                163
# Armenia                                                   23
# Australia                                                658
# Austria                                                  410
# Azerbaijan                                                14
# Bahamas                                                    2
# Bahrain                                                    4
# Bangladesh                                               144
# Barbados                                                   1
# ...

# %%
country_respondents=df['Country'].value_counts()

# %%
country_respondents
# Out:
# United States of America                                11095
# Germany                                                  4947
# India                                                    4231
# United Kingdom of Great Britain and Northern Ireland     3224
# Ukraine                                                  2672
# France                                                   2110
# Canada                                                   2104
# Poland                                                   1534
# Netherlands                                              1449
# Brazil                                                   1375
# Italy                                                    1341
# Australia                                                1260
# Spain                                                    1123
# Sweden                                                   1016
# Russian Federation                                        925
# ...

# %%
country_uses_python =country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_uses_python
# Out:
# Country
# Afghanistan                                               26
# Albania                                                   10
# Algeria                                                   37
# Andorra                                                    8
# Angola                                                     9
# Antigua and Barbuda                                        0
# Argentina                                                163
# Armenia                                                   23
# Australia                                                658
# Austria                                                  410
# Azerbaijan                                                14
# Bahamas                                                    2
# Bahrain                                                    4
# Bangladesh                                               144
# Barbados                                                   1
# ...

# %%
python_df = pd.concat([country_uses_python,country_respondents],axis='columns')

# %%
python_df
# Out:
#                                                       LanguageHaveWorkedWith  \
# Afghanistan                                                               26
# Albania                                                                   10
# Algeria                                                                   37
# Andorra                                                                    8
# Angola                                                                     9
# Antigua and Barbuda                                                        0
# Argentina                                                                163
# Armenia                                                                   23
# Australia                                                                658
# Austria                                                                  410
# Azerbaijan                                                                14
# ...

# %%
python_df.rename(columns={'LanguageHaveWorkedWith':'PythonUsers','Country':'Total'},inplace=True)

# %%
python_df['python_percentage']=python_df['PythonUsers']*100/python_df['Total']

# %%
python_df.sort_values(by='python_percentage',ascending=False)
# Out:
#                                                       PythonUsers  Total  \
# Lesotho                                                         1      1
# Niger                                                           1      1
# Belize                                                          2      2
# Central African Republic                                        1      1
# Chad                                                            1      1
# Dominica                                                        1      1
# Brunei Darussalam                                               3      3
# Saint Kitts and Nevis                                           1      1
# Samoa                                                           1      1
# Mauritania                                                      4      5
# Liberia                                                         3      4
# Congo, Republic of the...                                       6      8
# ...

# %%
python_df.loc[['India','Germany','United States of America','Switzerland','United Kingdom of Great Britain and Northern Ireland']]
# Out:
#                                                       PythonUsers  Total  \
# India                                                        2128   4231
# Germany                                                      2647   4947
# United States of America                                     6251  11095
# Switzerland                                                   466    876
# United Kingdom of Great Britain and Northern Ireland         1638   3224
#
#                                                       python_percentage
# India                                                         50.295438
# Germany                                                       53.507176
# United States of America                                      56.340694
# Switzerland                                                   53.196347
# United Kingdom of Great Britain and Northern Ireland          50.806452

# %%
df['YearsCode'].value_counts()
# Out:
# 10                    4561
# 5                     3723
# 6                     3496
# 8                     3449
# 7                     3333
# 4                     3290
# 15                    2813
# 20                    2636
# 12                    2559
# 3                     2518
# 9                     2251
# 14                    1822
# 25                    1671
# 2                     1642
# 11                    1636
# 13                    1477
# 30                    1461
# 16                    1401
# 18                    1228
# 17                    1038
# 40                     993
# 24                     870
# 22                     842
# 35                     735
# 1                      712
# 23                     634
# 26                     630
# Less than 1 year       569
# 19                     561
# 21                     522
# 28                     512
# 27                     504
# 32                     328
# 34                     293
# ...

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace=True)
df['YearsCode'].replace('More than 50 years',51,inplace=True)

# %%
df['YearsCode']=df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 14.197497870350265
